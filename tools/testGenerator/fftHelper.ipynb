# %% [markdown]
# fftFreqs tests:
# -----

# %%
import numpy as np

for i in range(1):
    n = np.around( np.random.randint(5,10, size =1)[0],decimals=3)
    d = np.around(np.random.rand(), decimals=3)
    freq = np.around(np.fft.fftfreq(n, d=d), decimals=3)
    print "result = {", ', '.join(map(str, freq)), "};"
    print "freqs = FFTHelper::fftFreq(", n , "," , d,");"
    print "for(int i = 0; i < int(result.n_elem); i++){"
    print "    CHECK_CLOSE(freqs[i], result[i], 1e-3);"
    print "}"
    print
# Out:
# result = { 0.0, 0.297, 0.593, -0.89, -0.593, -0.297 };
# freqs = FFTHelper::fftFreq( 6 , 0.562 );
# for(int i = 0; i < int(result.n_elem); i++){
#     CHECK_CLOSE(freqs[i], result[i], 1e-3);
# }

# %% [markdown]
# fftShift 1D tests:
# -----

# %%
for i in range(1):
    n = np.around( np.random.randint(5,10, size =1)[0],decimals=3)
    d = np.around(np.random.rand(), decimals=3)
    sig = np.around(np.fft.fftfreq(n, d=d), decimals=3)
    centered = np.fft.fftshift(sig)
    print "sig = {", ', '.join(map(str, sig)), "};"
    print "centered = {", ', '.join(map(str, centered)), "};"
    print "shifted = FFTHelper::fftShift(sig);"
    print "for(int i = 0; i < int(sig.n_elem); i++){"
    print "    CHECK_EQUAL(real(shifted[i]), real(centered[i]));"
    print "}"
    print
# Out:
# sig = { 0.0, 0.563, 1.127, -1.127, -0.563 };
# centered = { -1.127, -0.563, 0.0, 0.563, 1.127 };
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_elem); i++){
#     CHECK_EQUAL(real(shifted[i]), real(centered[i]));
# }

# %% [markdown]
# fftShift 2D tests:
# -----

# %%
for i in range(30):
    n = np.random.randint(1,6, size =2)
    sig = np.random.random_integers(-5,5, size=(n[0], n[1]))
    centered = np.fft.fftshift(sig)
    
    for j in range(n[0]):
        if(j ==0):
            print "sig <<", ' << '.join(map(str, sig[j,:])), "<< endr"
        elif(j == n[0]-1):
            print "   <<", ' << '.join(map(str, sig[j,:])), "<< endr;"
        else:
            print "   <<", ' << '.join(map(str, sig[j,:])), "<< endr"
    print        
    for j in range(n[0]):
        if(j == 0):
            print "centered <<", ' << '.join(map(str, centered[j,:])), "<< endr"
        elif(j == n[0]-1):
            print "        <<", ' << '.join(map(str, centered[j,:])), "<< endr;"
        else:
            print "        <<", ' << '.join(map(str, centered[j,:])), "<< endr"
    

    print "shifted = FFTHelper::fftShift(sig);"
    print "for(int i = 0; i < int(sig.n_rows); i++){"
    print "   for(int j = 0; j < int(sig.n_cols); j++){"
    print "    CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));"
    print "    }"
    print "}"
    print "/*------------------------------------------------------*/"
    print
# Out:
# sig << -5 << endr
#    << -2 << endr
#    << -2 << endr
#    << 0 << endr;
#
# centered << -2 << endr
#         << 0 << endr
#         << -5 << endr
#         << -2 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 0 << -5 << 2 << -3 << endr
#    << -3 << -2 << -3 << 2 << endr
#    << -5 << 3 << 3 << 3 << endr
#    << 1 << 4 << -5 << 5 << endr;
#
# centered << 3 << 3 << -5 << 3 << endr
#         << -5 << 5 << 1 << 4 << endr
#         << 2 << -3 << 0 << -5 << endr
#         << -3 << 2 << -3 << -2 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -3 << -5 << endr
#    << 1 << -2 << endr
#    << 5 << -5 << endr;
#
# centered << -5 << 5 << endr
#         << -5 << -3 << endr
#         << -2 << 1 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 0 << endr
#    << 1 << endr;
#
# centered << 1 << endr
#         << 0 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 5 << -5 << 1 << endr
#    << -4 << 3 << 0 << endr
#    << 5 << -5 << 2 << endr;
#
# centered << 2 << 5 << -5 << endr
#         << 1 << 5 << -5 << endr
#         << 0 << -4 << 3 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 0 << 2 << 3 << 3 << 4 << endr
#    << -5 << 1 << 4 << 3 << -2 << endr
#    << 2 << 0 << 4 << -3 << 4 << endr
#    << -2 << 2 << 0 << 0 << 2 << endr
#    << 4 << -5 << -1 << -3 << -5 << endr;
#
# centered << 0 << 2 << -2 << 2 << 0 << endr
#         << -3 << -5 << 4 << -5 << -1 << endr
#         << 3 << 4 << 0 << 2 << 3 << endr
#         << 3 << -2 << -5 << 1 << 4 << endr
#         << -3 << 4 << 2 << 0 << 4 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 1 << endr
#    << 5 << endr;
#
# centered << 5 << endr
#         << 1 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -2 << -1 << -5 << 5 << endr
#    << -1 << -5 << 0 << 3 << endr
#    << -1 << 5 << 3 << 0 << endr
#    << -5 << -2 << 2 << 2 << endr;
#
# centered << 3 << 0 << -1 << 5 << endr
#         << 2 << 2 << -5 << -2 << endr
#         << -5 << 5 << -2 << -1 << endr
#         << 0 << 3 << -1 << -5 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 5 << endr
#    << -5 << endr
#    << 0 << endr;
#
# centered << 0 << endr
#         << 5 << endr
#         << -5 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 4 << -1 << -3 << 4 << endr
#    << 3 << 5 << -2 << -2 << endr
#    << -2 << -3 << -4 << -3 << endr
#    << 3 << 1 << -3 << -1 << endr
#    << 2 << 5 << -2 << 5 << endr;
#
# centered << -3 << -1 << 3 << 1 << endr
#         << -2 << 5 << 2 << 5 << endr
#         << -3 << 4 << 4 << -1 << endr
#         << -2 << -2 << 3 << 5 << endr
#         << -4 << -3 << -2 << -3 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 0 << endr
#    << 5 << endr
#    << -1 << endr;
#
# centered << -1 << endr
#         << 0 << endr
#         << 5 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 0 << 2 << 0 << endr
#    << 1 << 4 << -5 << endr
#    << 5 << 3 << 1 << endr
#    << 2 << -2 << 5 << endr;
#
# centered << 1 << 5 << 3 << endr
#         << 5 << 2 << -2 << endr
#         << 0 << 0 << 2 << endr
#         << -5 << 1 << 4 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 4 << -2 << endr
#    << -5 << 0 << endr
#    << 0 << -4 << endr
#    << -3 << -3 << endr;
#
# centered << -4 << 0 << endr
#         << -3 << -3 << endr
#         << -2 << 4 << endr
#         << 0 << -5 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -4 << 2 << endr
#    << -2 << -5 << endr;
#
# centered << -5 << -2 << endr
#         << 2 << -4 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -2 << endr
#    << -5 << endr
#    << -1 << endr
#    << -2 << endr;
#
# centered << -1 << endr
#         << -2 << endr
#         << -2 << endr
#         << -5 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 4 << 3 << -2 << 5 << endr
#    << 3 << -3 << -2 << -4 << endr
#    << 5 << 2 << 5 << -2 << endr
#    << -4 << 4 << -5 << 1 << endr
#    << -2 << 3 << -5 << 3 << endr;
#
# centered << -5 << 1 << -4 << 4 << endr
#         << -5 << 3 << -2 << 3 << endr
#         << -2 << 5 << 4 << 3 << endr
#         << -2 << -4 << 3 << -3 << endr
#         << 5 << -2 << 5 << 2 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -3 << 3 << 0 << -2 << endr
#    << -5 << -2 << 2 << 3 << endr
#    << -5 << 1 << -5 << 3 << endr
#    << 5 << 0 << 4 << 0 << endr
#    << 2 << 1 << -3 << 2 << endr;
#
# centered << 4 << 0 << 5 << 0 << endr
#         << -3 << 2 << 2 << 1 << endr
#         << 0 << -2 << -3 << 3 << endr
#         << 2 << 3 << -5 << -2 << endr
#         << -5 << 3 << -5 << 1 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 1 << 2 << -5 << -3 << endr
#    << 5 << 0 << -4 << 5 << endr
#    << -1 << -1 << 5 << 0 << endr
#    << -3 << -1 << -4 << -5 << endr
#    << 3 << 0 << 2 << -1 << endr;
#
# centered << -4 << -5 << -3 << -1 << endr
#         << 2 << -1 << 3 << 0 << endr
#         << -5 << -3 << 1 << 2 << endr
#         << -4 << 5 << 5 << 0 << endr
#         << 5 << 0 << -1 << -1 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 3 << -5 << 1 << endr
#    << 2 << -3 << 2 << endr
#    << -4 << 5 << -2 << endr;
#
# centered << -2 << -4 << 5 << endr
#         << 1 << 3 << -5 << endr
#         << 2 << 2 << -3 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -4 << 4 << 0 << -3 << endr
#    << 2 << -3 << -2 << 5 << endr
#    << 4 << -5 << 4 << -2 << endr
#    << 4 << 4 << 0 << 0 << endr
#    << 2 << -4 << -3 << -1 << endr;
#
# centered << 0 << 0 << 4 << 4 << endr
#         << -3 << -1 << 2 << -4 << endr
#         << 0 << -3 << -4 << 4 << endr
#         << -2 << 5 << 2 << -3 << endr
#         << 4 << -2 << 4 << -5 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -4 << -3 << -3 << endr
#    << 0 << 3 << -3 << endr;
#
# centered << -3 << 0 << 3 << endr
#         << -3 << -4 << -3 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -2 << 0 << 1 << 0 << endr
#    << 1 << 4 << 3 << -5 << endr
#    << 1 << -4 << 0 << -4 << endr
#    << 2 << -5 << -2 << 0 << endr
#    << -3 << -3 << -3 << -5 << endr;
#
# centered << -2 << 0 << 2 << -5 << endr
#         << -3 << -5 << -3 << -3 << endr
#         << 1 << 0 << -2 << 0 << endr
#         << 3 << -5 << 1 << 4 << endr
#         << 0 << -4 << 1 << -4 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -3 << 1 << endr
#    << -2 << 4 << endr;
#
# centered << 4 << -2 << endr
#         << 1 << -3 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -3 << -5 << endr
#    << -3 << -1 << endr;
#
# centered << -1 << -3 << endr
#         << -5 << -3 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -3 << 4 << endr
#    << -1 << 0 << endr
#    << 1 << -2 << endr;
#
# centered << -2 << 1 << endr
#         << 4 << -3 << endr
#         << 0 << -1 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 2 << 2 << 0 << endr
#    << 4 << -2 << 5 << endr
#    << -1 << 4 << 4 << endr;
#
# centered << 4 << -1 << 4 << endr
#         << 0 << 2 << 2 << endr
#         << 5 << 4 << -2 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -2 << 0 << 0 << endr
#    << 4 << -4 << -5 << endr;
#
# centered << -5 << 4 << -4 << endr
#         << 0 << -2 << 0 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -4 << -5 << endr
#
# centered << -5 << -4 << endr
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << 3 << 2 << 5 << 2 << endr
#
# centered << 5 << 2 << 3 << 2 << endr
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
#
# sig << -4 << 5 << endr
#    << 3 << 3 << endr
#    << -1 << -4 << endr
#    << 0 << 2 << endr
#    << 0 << 3 << endr;
#
# centered << 2 << 0 << endr
#         << 3 << 0 << endr
#         << 5 << -4 << endr
#         << 3 << 3 << endr
#         << -4 << -1 << endr;
# shifted = FFTHelper::fftShift(sig);
# for(int i = 0; i < int(sig.n_rows); i++){
#    for(int j = 0; j < int(sig.n_cols); j++){
#     CHECK_EQUAL(real(shifted(i,j)), real(centered(i,j)));
#     }
# }
# /*------------------------------------------------------*/
